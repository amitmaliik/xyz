# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
quora = pd.read_csv('quora_questions.csv',encoding='ISO-8859-1')
quora['Question'] = quora['Question']

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english',encoding = "ISO-8859-1")

# %%
dtm = tfidf.fit_transform(quora['Question'])

# %%
dtm
# Out:
# <404289x39076 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2004134 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF

# %%
nmf_model = NMF(n_components=20,random_state=42)

# %%
nmf_model.fit(dtm)
# Out:
# NMF(alpha=0.0, beta=1, eta=0.1, init=None, l1_ratio=0.0, max_iter=200,
#   n_components=20, nls_max_iter=2000, random_state=42, shuffle=False,
#   solver='cd', sparseness=None, tol=0.0001, verbose=0)

# %%
for index,Question in enumerate(nmf_model.components_):
    print('THE TOP 15 WORDS FOR Question '.format(index))
    print([tfidf.get_feature_names()[i] for i in Question.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR Question
# ['site', 'read', 'place', 'visit', 'places', 'phone', 'buy', 'laptop', 'movie', 'ways', '2016', 'books', 'book', 'movies', 'best']
#
#
# THE TOP 15 WORDS FOR Question
# ['majors', 'recruit', 'sex', 'looking', 'differ', 'use', 'exist', 'really', 'compare', 'cost', 'long', 'feel', 'work', 'mean', 'does']
#
#
# THE TOP 15 WORDS FOR Question
# ['add', 'answered', 'needing', 'post', 'easily', 'improvement', 'delete', 'asked', 'google', 'answers', 'answer', 'ask', 'question', 'questions', 'quora']
#
#
# THE TOP 15 WORDS FOR Question
# ['america', 'presidency', 'happen', '2016', 'presidential', 'think', 'vote', 'better', 'election', 'win', 'hillary', 'president', 'clinton', 'donald', 'trump']
#
#
# THE TOP 15 WORDS FOR Question
# ['indian', 'companies', 'don', 'guy', 'men', 'culture', 'women', 'work', 'girls', 'live', 'girl', 'look', 'sex', 'feel', 'like']
#
#
# THE TOP 15 WORDS FOR Question
# ['resolutions', 'resolution', 'blowing', 'mind', 'likes', 'girl', '2017', 'year', 'don', 'employees', 'going', 'day', 'things', 'new', 'know']
#
#
# THE TOP 15 WORDS FOR Question
# ['communication', 'pronunciation', 'python', 'languages', 'writing', 'speaking', 'java', 'learning', 'speak', 'skills', 'improve', 'programming', 'language', 'english', 'learn']
#
#
# THE TOP 15 WORDS FOR Question
# ['doesn', 'marriage', 'make', 'feel', 'girlfriend', 'tell', 'forget', 'really', 'friend', 'know', 'true', 'person', 'girl', 'fall', 'love']
#
#
# THE TOP 15 WORDS FOR Question
# ['balance', 'earth', 'day', 'death', 'changed', 'want', 'change', 'live', 'moment', 'real', 'thing', 'important', 'meaning', 'purpose', 'life']
#
#
# THE TOP 15 WORDS FOR Question
# ['earth', 'stop', 'blowing', 'use', 'easily', 'mind', 'google', 'flat', 'questions', 'hate', 'believe', 'ask', 'don', 'think', 'people']
#
#
# THE TOP 15 WORDS FOR Question
# ['diet', 'help', 'healthy', 'exercise', 'month', 'pounds', 'reduce', 'quickly', 'loss', 'fast', 'fat', 'ways', 'gain', 'lose', 'weight']
#
#
# THE TOP 15 WORDS FOR Question
# ['using', 'website', 'investment', 'friends', 'black', 'internet', 'free', 'home', 'easy', 'youtube', 'ways', 'earn', 'online', 'make', 'money']
#
#
# THE TOP 15 WORDS FOR Question
# ['reservation', 'engineering', 'business', 'company', 'president', 'minister', 'china', 'country', 'olympics', 'available', 'job', 'spotify', 'war', 'pakistan', 'india']
#
#
# THE TOP 15 WORDS FOR Question
# ['feel', 'real', 'having', 'long', 'spend', 'person', 'machine', 'job', 'favorite', 'movies', 'home', 'sex', 'possible', 'travel', 'time']
#
#
# THE TOP 15 WORDS FOR Question
# ['account', 'business', 'java', 'programming', 'mechanical', 'better', 'learning', 'use', 'job', 'data', 'software', 'science', 'computer', 'engineering', 'difference']
#
#
# THE TOP 15 WORDS FOR Question
# ['russia', 'live', 'going', 'better', 'think', 'coming', 'countries', 'place', 'pakistan', 'happen', 'end', 'country', 'iii', 'war', 'world']
#
#
# THE TOP 15 WORDS FOR Question
# ['hack', 'start', 'quickest', 'facebook', 'increase', 'painless', 'instagram', 'learn', 'account', 'best', 'commit', 'fastest', 'suicide', 'easiest', 'way']
#
#
# THE TOP 15 WORDS FOR Question
# ['modi', 'money', 'currency', 'economy', 'government', 'think', 'ban', 'banning', 'black', 'indian', 'rupee', 'rs', '1000', 'notes', '500']
#
#
# THE TOP 15 WORDS FOR Question
# ['provider', 'ca', 'balance', 'departments', 'positions', 'movies', 'songs', 'read', 'job', 'work', 'engineering', 'ways', 'bad', 'books', 'good']
#
#
# THE TOP 15 WORDS FOR Question
# ['big', 'election', 'die', 'really', 'come', 'movie', 'want', 'battle', '2016', 'learning', 'win', 'thing', 'business', 'start', 'did']

# %%
topic_results = nmf_model.transform(dtm)

# %%
topic_results.argmax(axis=1)
# Out:
# array([12,  7, 16, ..., 17, 17,  4])

# %%
quora['Topic'] = topic_results.argmax(axis=1)

# %%
quora.Topic = quora.Topic.astype(str)
label ={'0' : 'Sci-Fi Movies', '1' : 'music broke', '2' : 'battle_gaming', '3' : 'funny', '4' : 'gaming', '5' : 'movie_game', '6' : 'game', '7' : 'sci-fi', '8' : 'buddha_snake_sword', '9':'gaming_indoor', '10':'GOT_fiction_TV', '11':'racing_sports_games','12':'trailers','13':'seasons_gameplay_festival','14':'News_cooking_bloopers','15':'sports_moments_outdoor','16':'car_sports_racing', '17':'explained-sci-fi', '18':'gaming console', '19':'discover/documentary'} 
quora['category'] = quora['Topic'].map(label)

# %%
i=input("ur interests")
quora[quora.category == i]
# Out:
# ur interestsfunny
#                                                  Question Topic category
# 15      What would a Trump presidency mean for current...     3    funny
# 64      Where can I find a European family office data...     3    funny
# 142     Which one is better polo diesel or grand i10 p...     3    funny
# 155                   Could Snoke secretly be Darth Maul?     3    funny
